# %%
#Import Libraries
import pandas as pd #Data processing, csv file
import numpy as np #Linear algebra
import matplotlib.pyplot as plt #Visualization

# %%
#Read data set
dataset = pd.read_csv("philippinesData.csv")

# %%
#Convert PH pesos into US dollars
#Find the total cost of expenditures 
    #USE a list

# %%
#This is the test to see if the data set loaded
dataset.head()
# Out:
#    Total Household Income Region  Total Food Expenditure  \
# 0                  480332    CAR                  117848
# 1                  198235    CAR                   67766
# 2                   82785    CAR                   61609
# 3                  107589    CAR                   78189
# 4                  189322    CAR                   94625
#
#   Main Source of Income  Agricultural Household indicator  \
# 0         Wage/Salaries                                 0
# 1         Wage/Salaries                                 0
# 2         Wage/Salaries                                 1
# 3         Wage/Salaries                                 0
# 4         Wage/Salaries                                 0
#
#    Bread and Cereals Expenditure  Total Rice Expenditure  Meat Expenditure  \
# 0                          42140                   38300             24676
# 1                          17329                   13008             17434
# ...

# %%
#This is my first list
#I only want to grab columns with the word "expenditures" (Do I use a for loop?)
expenditures = dataset[["Bread and Cereals Expenditure", "Total Rice Expenditure", "Marine Expenditure", "Meat Expenditure", 
                        "Fruit Expenditure", "Vegetables Expenditure", "Restaurant and hotels Expenditure",
                       "Alcoholic Beverages Expenditure", "Tobacco Expenditure", "Clothing, Footwear and Other Wear Expenditure",
                       "Housing and water Expenditure", "Medical Care Expenditure", "Transportation Expenditure",
                       "Communication Expenditure", "Education Expenditure", "Miscellaneous Goods and Services Expenditure",
                       "Special Occasions Expenditure"]]

expenditures.head(41545) #This is the total amount in the data set
# Out:
#        Bread and Cereals Expenditure  Total Rice Expenditure  \
# 0                              42140                   38300
# 1                              17329                   13008
# 2                              34182                   32001
# 3                              34030                   28659
# 4                              34820                   30167
# ...                              ...                     ...
# 41539                          23675                   21542
# 41540                           2691                    1273
# 41541                          28646                   27339
# 41542                          29996                   26655
# 41543                          43485                   41205
#
#        Marine Expenditure  Meat Expenditure  Fruit Expenditure  \
# 0                   16806             24676               3325
# 1                   11073             17434               2035
# ...

# %%
#Currency Convert
    # Philippine Peso to US Dollar = 48.65

# %%
#This allows me to see all the columns that are in the whole data set
dataset.columns
# Out:
# Index(['Total Household Income', 'Region', 'Total Food Expenditure',
#        'Main Source of Income', 'Agricultural Household indicator',
#        'Bread and Cereals Expenditure', 'Total Rice Expenditure',
#        'Meat Expenditure', 'Marine Expenditure', 'Fruit Expenditure',
#        'Vegetables Expenditure', 'Restaurant and hotels Expenditure',
#        'Alcoholic Beverages Expenditure', 'Tobacco Expenditure',
#        'Clothing, Footwear and Other Wear Expenditure',
#        'Housing and water Expenditure', 'Imputed House Rental Value',
#        'Medical Care Expenditure', 'Transportation Expenditure',
#        'Communication Expenditure', 'Education Expenditure',
#        'Miscellaneous Goods and Services Expenditure',
#        'Special Occasions Expenditure', 'Crop Farming and Gardening expenses',
#        'Total Income from Entrepreneurial Acitivites', 'Household Head Sex',
#        'Household Head Age', 'Household Head Marital Status',
# ...

# %%
#Read each row
for exp, row in expenditures.iterrows():
    print(exp, row["Meat Expenditure"])
# Out:
# 0 24676
# 1 17434
# 2 7783
# 3 10914
# 4 18391
# 5 15336
# 6 12968
# 7 14640
# 8 11464
# 9 26488
# 10 11174
# 11 20548
# 12 14322
# 13 10034
# 14 5430
# 15 10336
# 16 11226
# 17 9840
# 18 8048
# 19 10162
# 20 6638
# 21 7510
# 22 11884
# 23 8276
# 24 9562
# 25 12557
# 26 7937
# 27 15591
# 28 15018
# 29 12006
# 30 14040
# 31 19552
# 32 16800
# 33 18876
# 34 12476
# 35 11908
# 36 5796
# 37 11810
# 38 12088
# 39 14958
# 40 15101
# 41 9937
# 42 8324
# 43 23704
# 44 29084
# 45 8002
# 46 12686
# 47 16505
# 48 18464
# 49 30450
# 50 14050
# 51 46818
# 52 15204
# 53 25452
# 54 25542
# 55 12474
# 56 36464
# 57 11174
# 58 8195
# 59 12101
# 60 61482
# 61 7039
# 62 6530
# 63 18616
# 64 8885
# 65 15810
# 66 11649
# 67 8073
# 68 9174
# 69 9303
# 70 8840
# 71 10385
# 72 14649
# 73 10822
# 74 9279
# 75 12892
# 76 13902
# 77 3621
# 78 10224
# 79 21917
# 80 12906
# 81 10713
# 82 10489
# 83 15818
# 84 8762
# 85 7087
# 86 9961
# 87 23506
# 88 54002
# 89 10892
# 90 10508
# 91 7923
# 92 15165
# 93 8590
# ...

# %%
#Search specific things
dataset.loc[dataset["Meat Expenditure"] >= 100000]

#After doing this I'm actually super surprised that there are only 13 families/persons who are able to spend 100,000
    #or more yearly on meat!
# Out:
#        Total Household Income                  Region  Total Food Expenditure  \
# 460                   1538900                  Caraga                  525265
# 530                   1606308                  Caraga                  720007
# 8474                   755036        IVA - CALABARZON                  318097
# 11665                 2540380       XI - Davao Region                  522836
# 15152                 2231340     II - Cagayan Valley                  339768
# 16449                   74704       I - Ilocos Region                  135797
# 17026                  565072        IVA - CALABARZON                  298419
# 19693                 2162240  VIII - Eastern Visayas                  356258
# 21701                  374759   X - Northern Mindanao                  203002
# 24624                   91201      XII - SOCCSKSARGEN                  164698
# 39419                 2500000                     NCR                  603187
# ...

# %%
#Search specific things
expenditures.loc[expenditures["Alcoholic Beverages Expenditure"] >= 10000]

#How do I order things in ascending or descending values?

#What I realized I should do is, I should add up the total expenditures and compare that to "Total Household Income"
    # 1.) Once I figure that out I want to see some correlation between Alcohol expenses and income. I assume the more
        #income one makes the more they are going to spend on alcohol
    # 2.)
# Out:
#        Bread and Cereals Expenditure  Total Rice Expenditure  \
# 195                            18411                   12667
# 391                            23664                   22620
# 460                            64174                   38088
# 490                            20948                   16440
# 528                            17756                   11674
# ...                              ...                     ...
# 40415                          27368                   21390
# 40439                          32028                   17370
# 40440                          43174                   28567
# 40658                          34183                   13950
# 41511                          27025                   21270
#
#        Marine Expenditure  Meat Expenditure  Fruit Expenditure  \
# 195                 12469             12556               2100
# 391                  9278             10546                850
# ...

# %%
expenditures[""]
